# %%
# !pip install tensorflow
# !pip install numpy
# !pip install matplotlib
# !pip install pillow
# !pip install transformers
# !pip install tf-keras
# !pip install sentencepiece

# %%
# !pip install --upgrade sentencepiece

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array  # Changed: Directly imported load_img and img_to_array
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import random
import os
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import MarianMTModel, MarianTokenizer

# %%
#no top layers as i have add my own layers for classification of plant datas that are divided into 15 classes
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
#my custom layers
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Reduce the dimensions
x = Dense(1024, activation='relu')(x)  # Add a dense layer with 1024 neurons
predictions = Dense(4, activation='softmax')(x)  # Final layer for 15 classes

# Create a new model combining base VGG16 and custom layers
model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
# Define the path to save the model
model_save_path = 'plant_disease_model.h5'

# %%
for layer in base_model.layers:
    layer.trainable = False #freezing layers

# %%
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data augmentation for training and validation split
datagen = ImageDataGenerator(
    rescale=1./255,        
    shear_range=0.2,       
    zoom_range=0.2,        
    horizontal_flip=True,  
    validation_split=0.2   
)

# %%
# Path to the dataset
dataset_dir = 'PlantVillage'

# Training data generator
train_generator = datagen.flow_from_directory(
    dataset_dir,
    target_size=(224, 224),          # Resize all images to 224x224 (VGG16 input size)
    batch_size=32,                   # Batch size
    class_mode='categorical',        # Multiple classes
    subset='training'                # Set for training data
)

# Validation data generator
validation_generator = datagen.flow_from_directory(
    dataset_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'              # Set for validation data
)
# Out:
# Found 2494 images belonging to 4 classes.
# Found 622 images belonging to 4 classes.

# %%
 # Train the model
history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // train_generator.batch_size,
        epochs=5,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // validation_generator.batch_size
    )
# Out:
# Epoch 1/5
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 632s 8s/step - accuracy: 0.7314 - loss: 0.7645 - val_accuracy: 0.9391 - val_loss: 0.1983
# Epoch 2/5
#  1/77 ━━━━━━━━━━━━━━━━━━━━ 7:57 6s/step - accuracy: 0.9375 - loss: 0.1706
# /opt/anaconda3/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# ...

# %% [markdown]
# #no way

# %%
# Save the trained model
model.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to plant_disease_model.h5

# %%
# Load the saved model
loaded_model = load_model(model_save_path)
print("Model loaded successfully")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully

# %%
# Detected disease HELSINKI MODEL
disease = "Tomato Leaf Blight"

# Basic information about the disease
treatment_recommendations = {
    "Tomato Leaf Blight": {
        "description": "Tomato Leaf Blight is a fungal disease caused by Alternaria solani, which causes dark brown spots on leaves, leading to leaf drop.",
        "treatment": "Remove affected leaves to prevent the spread. Apply copper-based fungicides weekly, especially in humid conditions. Rotate crops to prevent recurrence.",
        "prevention": "Ensure proper plant spacing for air circulation, and avoid overhead watering."
    }
}

# Multilingual support (English and Hindi example)
language = "Hindi"  # Could be dynamically selected based on user

# NLP for natural language generation and translation
from transformers import pipeline

# Define a summary of the diagnosis and treatment (in English)
diagnosis_summary = (
    f"The detected disease is {disease}. {treatment_recommendations[disease]['description']} "
    f"To treat it, {treatment_recommendations[disease]['treatment']} "
    f"For prevention, {treatment_recommendations[disease]['prevention']}."
)

# Translate if necessary
if language == "Hindi":
    translator = pipeline("translation", model="Helsinki-NLP/opus-mt-en-hi")
    translated = translator(diagnosis_summary)[0]['translation_text']
    print("Translated Recommendation (Hindi):\n", translated)
else:
    print("English Recommendation:\n", diagnosis_summary)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Translated Recommendation (Hindi):
#  यह पता लगाने के लिए मिलित रोग है _BAR_ टन लेगो ला मॉफ़ॉफ बॉथ एक मज़ेदार पदार्थ है जो अलीआ सोर्निया के पत्तेों को जन्म देता है _BAR_ इसका इलाज करने के लिए, प्रभावित पत्तेों को बढ़ने से रोकने के लिए हटा देते हैं _BAR_ इसके प्रभाव को प्रभावित करते हैं _BAR_ विशेषकर हवा की मात्रा को पीछे छोड़ते हैं _BAR_ पौधों को मज़बूत करने से रोकने के लिए बीज की प्रक्रिया को रोकने से रोकने के लिए ।

# %%
# Detected disease facebook model
from transformers import pipeline
from transformers import pipeline

def disease_description(predicted_class_name, language="English"):
    # Basic information about the diseases
    treatment_recommendations = {
        "Tomato Leaf Blight": {
            "description": "Tomato Leaf Blight is a fungal disease caused by Alternaria solani, which causes dark brown spots on leaves, leading to leaf drop.",
            "treatment": "Remove affected leaves to prevent the spread. Apply copper-based fungicides weekly, especially in humid conditions. Rotate crops to prevent recurrence.",
            "prevention": "Ensure proper plant spacing for air circulation, and avoid overhead watering."
            },
        "Tomato Healthy": {
            "description": "The tomato plant is healthy and free from disease.",
            "treatment": "No treatment necessary. Maintain regular care and monitoring.",
            "prevention": "Continue with routine care and avoid potential exposure to diseases."
        },
        "Potato Healthy": {
            "description": "The potato plant is healthy and free from disease.",
            "treatment": "No treatment necessary. Continue regular care and monitoring.",
            "prevention": "Ensure proper crop rotation and maintain good soil health."
        },
        "Tomato Mosaic Virus": {
            "description": "Tomato Mosaic Virus (ToMV) is a viral disease causing mottled or mosaic-like patterns on leaves, stunted growth, and reduced yield.",
            "treatment": "Remove and destroy infected plants. Disinfect tools and equipment. There is no chemical cure for viral diseases.",
            "prevention": "Use virus-resistant tomato varieties, practice good sanitation, and avoid handling plants when they are wet."
        }
    }
    
    # Get the relevant information
    if predicted_class_name in treatment_recommendations:
        description = treatment_recommendations[predicted_class_name]['description']
        treatment = treatment_recommendations[predicted_class_name]['treatment']
        prevention = treatment_recommendations[predicted_class_name]['prevention']
    else:
        return "Disease not found in the recommendations."
    
    # Define a summary of the diagnosis and treatment
    diagnosis_summary = (
        f"The detected disease is {predicted_class_name}. {description} "
        f"To treat it, {treatment} "
        f"For prevention, {prevention}."
    )
    
    # Translate if necessary
    if language == "Hindi":
        translator = pipeline("translation", model="facebook/m2m100_418M")
        translated = translator(diagnosis_summary, src_lang="en", tgt_lang="hi")[0]['translation_text']
        return f"Translated Recommendation (Hindi):\n{translated}"
    else:
        return f"English Recommendation:\n{diagnosis_summary}"

# Example usage
print(disease_description("Tomato Healthy", "Hindi"))
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Translated Recommendation (Hindi):
# बीमारी का पता लगाया जाता है टमाटर स्वस्थ है. टमाटर पौधा स्वस्थ है और बीमारी से मुक्त है. इलाज के लिए, कोई उपचार आवश्यक नहीं है. नियमित देखभाल और निगरानी बनाए रखें. रोकथाम के लिए, नियमित देखभाल जारी रखें और बीमारियों के संभावित संपर्क से बचें..

# %%
# Function to load and preprocess image
def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))  # Load and resize image
    img_array = image.img_to_array(img)  # Convert image to array
    img_array = np.expand_dims(img_array, axis=0)  # Expand dimensions to fit model input shape
    img_array /= 255.0  # Rescale pixel values to 0-1
    return img_array

# Function to display image and predictions
def display_image_and_prediction(model, image_path, class_labels):
    # Preprocess image
    img_array = load_and_preprocess_image(image_path)
    
    # Make prediction
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions, axis=1)[0]  # Get predicted class index
    
    # Display image
    img = image.load_img(image_path)
    plt.imshow(img)
    plt.axis('off')
    
    # Get actual class from the file path (parent folder of the image)
    actual_class = os.path.basename(os.path.dirname(image_path))
    
    # Display predicted and actual class
    plt.title(f"Actual: {actual_class}, Predicted: {class_labels[predicted_class]}")
    plt.show()
    
    result = disease_description("class_labels[predicted_class]", "Hindi")
    print(result)

# Function to randomly select an image from the dataset
def get_random_image(directory):
    class_folder = random.choice(os.listdir(directory))  # Select random class folder
    class_folder_path = os.path.join(directory, class_folder)
    image_file = random.choice(os.listdir(class_folder_path))  # Select random image file
    image_path = os.path.join(class_folder_path, image_file)
    return image_path

# %%
# Function to randomly select an image from the dataset
def get_random_image(directory):
    # Filter out non-directory files (e.g., '.DS_Store')
    class_folders = [folder for folder in os.listdir(directory) if os.path.isdir(os.path.join(directory, folder))]
    
    class_folder = random.choice(class_folders)  # Select random class folder
    class_folder_path = os.path.join(directory, class_folder)
    
    image_file = random.choice(os.listdir(class_folder_path))  # Select random image file
    image_path = os.path.join(class_folder_path, image_file)
    
    return image_path

# %%
# Define the class labels in the order they were used in training
class_labels = ['Potato Late Blight', 'Potato Healthy', 'Tomato Mosaic Virus', 'Tomato Healthy']

# Path to the dataset
dataset_dir = 'PlantVillage'

# Test the model on 5 random images
for i in range(1):
    random_image_path = get_random_image(dataset_dir)
    display_image_and_prediction(model, random_image_path, class_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# Disease not found in the recommendations.
